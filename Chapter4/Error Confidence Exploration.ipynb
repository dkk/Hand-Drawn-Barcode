# %% [markdown]
# This notebook explores the confidence the model has in errors compared to right answers.

# %%
BARS_PATH = "../bars/test/"

# %% [markdown]
# # Import & Load the Bar Categorization Model

# %%
import time
import tensorflow as tf

# %%
print('Loading categorization model...', end='')
start_time = time.time()

cat_model = tf.keras.models.load_model('./exported-models/bar_cat_EfficientNetB2_9723')

end_time = time.time()
elapsed_time = end_time - start_time
print('Done! Took {} seconds'.format(elapsed_time))
# Out:
# Loading categorization model...WARNING:tensorflow:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_68689) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_64453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_71207) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference__wrapped_model_37983) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_51703) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_45821) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_45913) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_51310) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block7b_expand_activation_layer_call_and_return_conditional_losses_80389) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6e_se_reduce_layer_call_and_return_conditional_losses_79493) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_80954) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_52971) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block3c_se_reduce_layer_call_and_return_conditional_losses_72445) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_78387) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_76043) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_70101) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block3c_expand_activation_layer_call_and_return_conditional_losses_48636) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_50923) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block2c_se_reduce_layer_call_and_return_conditional_losses_70833) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_73878) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block1b_se_reduce_layer_call_and_return_conditional_losses_69221) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_69595) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_68828) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_73325) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block4d_activation_layer_call_and_return_conditional_losses_50436) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_73464) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block3c_activation_layer_call_and_return_conditional_losses_72405) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_49904) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_71386) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_78900) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_51750) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_46928) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_71892) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_52491) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5d_se_reduce_layer_call_and_return_conditional_losses_52190) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_73504) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_48335) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_49556) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_78761) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block4d_expand_activation_layer_call_and_return_conditional_losses_50344) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5b_activation_layer_call_and_return_conditional_losses_75629) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block1b_activation_layer_call_and_return_conditional_losses_69181) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_52631) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block2c_expand_activation_layer_call_and_return_conditional_losses_70654) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_49996) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_77149) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block4d_se_reduce_layer_call_and_return_conditional_losses_74610) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_45960) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_53018) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block7b_activation_layer_call_and_return_conditional_losses_80532) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_53319) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_50043) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_75669) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_77794) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5d_expand_activation_layer_call_and_return_conditional_losses_52051) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_69774) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6e_expand_activation_layer_call_and_return_conditional_losses_54199) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block7b_se_reduce_layer_call_and_return_conditional_losses_55175) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_49076) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5d_activation_layer_call_and_return_conditional_losses_52143) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block4d_activation_layer_call_and_return_conditional_losses_74570) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6e_activation_layer_call_and_return_conditional_losses_79453) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block7b_activation_layer_call_and_return_conditional_losses_55128) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_54735) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_47067) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block2c_activation_layer_call_and_return_conditional_losses_47460) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_76222) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block7b_expand_activation_layer_call_and_return_conditional_losses_55034) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_77655) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6e_se_reduce_layer_call_and_return_conditional_losses_54338) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_53898) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_71713) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_54641) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block2c_se_reduce_layer_call_and_return_conditional_losses_47507) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_72998) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_53458) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_53851) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_68868) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6e_activation_layer_call_and_return_conditional_losses_54291) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_77288) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_52879) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# ...
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_functional_1_layer_call_and_return_conditional_losses_66754) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_49603) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_74057) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block3c_se_reduce_layer_call_and_return_conditional_losses_48775) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_49464) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5d_activation_layer_call_and_return_conditional_losses_76735) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_55480) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_47020) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_50876) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_70280) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_72819) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_53759) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block3c_activation_layer_call_and_return_conditional_losses_48728) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_53411) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_70240) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block2c_activation_layer_call_and_return_conditional_losses_70793) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_75490) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_46540) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_46680) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_79871) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_50784) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_80014) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_52584) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_76182) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_51171) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_49216) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_51611) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_74017) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_78347) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_71346) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_46633) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_78940) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_48288) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_49169) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_72958) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_77834) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5d_se_reduce_layer_call_and_return_conditional_losses_76775) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5b_activation_layer_call_and_return_conditional_losses_51263) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_80054) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block7b_se_reduce_layer_call_and_return_conditional_losses_80572) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_71852) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_75163) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_47948) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block2c_expand_activation_layer_call_and_return_conditional_losses_47368) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block1b_se_reduce_layer_call_and_return_conditional_losses_46239) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_47808) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block4d_expand_activation_layer_call_and_return_conditional_losses_74431) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_48196) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_77328) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block4d_se_reduce_layer_call_and_return_conditional_losses_50483) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block1b_activation_layer_call_and_return_conditional_losses_46192) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5d_expand_activation_layer_call_and_return_conditional_losses_76596) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_74984) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block3c_expand_activation_layer_call_and_return_conditional_losses_72266) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_69734) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_47901) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_54782) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_75123) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6e_expand_activation_layer_call_and_return_conditional_losses_79314) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:tensorflow:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_78208) with ops with custom gradients. Will likely fail if a gradient is requested.
# Done! Took 51.68789505958557 seconds

# %% [markdown]
# ## Model evaluation

# %%
from os import listdir
from os.path import isfile, join

paths = [BARS_PATH + f for f in listdir(BARS_PATH) if isfile(join(BARS_PATH, f))]
paths
# Out:
# ['../bars/test/1000767_h_1018431.png',
#  '../bars/test/1001347_v_794159.png',
#  '../bars/test/1002872_1.png',
#  '../bars/test/1004288_h_1024768.png',
#  '../bars/test/1007758_h_1019981.png',
#  '../bars/test/1008617_108.png',
#  '../bars/test/1011307_80.png',
#  '../bars/test/1018431_123.png',
#  '../bars/test/1018691_hv_794159.png',
#  '../bars/test/1019572_h_1002872.png',
#  '../bars/test/1019981_4.png',
#  '../bars/test/1020886_h_1008617.png',
#  '../bars/test/1023383_h_1011307.png',
#  '../bars/test/1024768_40.png',
#  '../bars/test/102978_hv_530532.png',
#  '../bars/test/1033503_v_1018431.png',
#  '../bars/test/1034799_hv_1018431.png',
#  '../bars/test/1037827_v_788159.png',
#  '../bars/test/1042691_hv_788159.png',
#  '../bars/test/125743_v_1002872.png',
#  '../bars/test/126748_v_233336.png',
#  '../bars/test/137676_hv_210504.png',
#  '../bars/test/147052_16.png',
#  '../bars/test/148410_v_384036.png',
#  '../bars/test/156033_v_530532.png',
#  '../bars/test/165507_hv_796968.png',
#  '../bars/test/16775_v_923680.png',
#  '../bars/test/174405_hv_333480.png',
#  '../bars/test/178606_hv_763624.png',
#  '../bars/test/186143_hv_1002872.png',
#  '../bars/test/188204_hv_233336.png',
#  '../bars/test/210504_60.png',
#  '../bars/test/211332_h_210504.png',
#  '../bars/test/215763_132.png',
#  '../bars/test/217012_h_233336.png',
#  '../bars/test/221918_hv_751772.png',
#  '../bars/test/223172_v_147052.png',
#  '../bars/test/230883_h_215763.png',
#  '../bars/test/233336_65.png',
#  '../bars/test/233965_v_751772.png',
#  '../bars/test/236488_hv_147052.png',
#  '../bars/test/268601_h_534070.png',
#  '../bars/test/271512_h_530532.png',
#  '../bars/test/273053_5.png',
#  '../bars/test/278581_h_557114.png',
#  '../bars/test/284017_v_584354.png',
#  '../bars/test/284569_v_630434.png',
#  '../bars/test/286167_2.png',
#  '../bars/test/294766_v_487394.png',
#  '../bars/test/301445_h_550474.png',
#  '../bars/test/316753_h_584354.png',
#  '../bars/test/3167_v_1024768.png',
#  '../bars/test/3247_hv_1024768.png',
#  '../bars/test/329481_96.png',
#  '../bars/test/330457_hv_424453.png',
#  '../bars/test/333480_42.png',
#  '../bars/test/33355_hv_923680.png',
#  '../bars/test/337505_v_550474.png',
#  '../bars/test/345326_hv_766229.png',
#  '../bars/test/363459_v_802074.png',
#  '../bars/test/376849_v_557114.png',
#  '../bars/test/378763_v_859706.png',
#  '../bars/test/379307_v_874810.png',
#  '../bars/test/383191_48.png',
#  '../bars/test/384036_128.png',
#  '../bars/test/386803_131.png',
#  '../bars/test/388995_hv_798645.png',
#  '../bars/test/389639_hv_854261.png',
#  '../bars/test/391774_v_501242.png',
#  '../bars/test/396549_hv_329481.png',
#  '../bars/test/403374_h_596829.png',
#  '../bars/test/404107_69.png',
#  '../bars/test/410155_hv_952345.png',
#  '../bars/test/417659_hv_974681.png',
#  '../bars/test/421201_h_630434.png',
#  '../bars/test/424453_26.png',
#  '../bars/test/438723_94.png',
#  '../bars/test/440323_h_619523.png',
#  '../bars/test/441503_hv_1008617.png',
#  '../bars/test/443969_v_534070.png',
#  '../bars/test/462959_hv_1019981.png',
#  '../bars/test/470190_hv_762765.png',
#  '../bars/test/471259_61.png',
#  '../bars/test/480078_h_762765.png',
#  '../bars/test/481748_h_763624.png',
#  '../bars/test/482886_hv_596829.png',
#  '../bars/test/486017_hv_273053.png',
#  '../bars/test/487394_129.png',
#  '../bars/test/487978_h_766229.png',
#  '../bars/test/498199_v_951710.png',
#  '../bars/test/501242_135.png',
#  '../bars/test/504940_h_751772.png',
#  '../bars/test/521815_26.png',
#  '../bars/test/529774_h_273053.png',
#  '../bars/test/530532_29.png',
#  '../bars/test/534070_99.png',
#  '../bars/test/54499_h_59603.png',
#  '../bars/test/550474_67.png',
#  '../bars/test/557114_2.png',
#  '../bars/test/567986_hv_584354.png',
#  '../bars/test/568166_hv_630434.png',
#  '../bars/test/569067_h_286167.png',
#  '../bars/test/573341_hv_487394.png',
#  '../bars/test/584354_77.png',
#  '../bars/test/593418_v_329481.png',
#  '../bars/test/595271_h_404107.png',
#  '../bars/test/59603_10.png',
#  '../bars/test/596829_83.png',
#  '../bars/test/619203_h_438723.png',
#  '../bars/test/619523_134.png',
#  '../bars/test/621679_v_1008617.png',
#  '../bars/test/622871_v_952345.png',
#  '../bars/test/630434_83.png',
#  '../bars/test/634807_v_974681.png',
#  '../bars/test/636170_h_424453.png',
#  '../bars/test/641410_hv_534070.png',
#  '../bars/test/656870_v_424453.png',
#  '../bars/test/658182_h_329481.png',
#  '../bars/test/661906_hv_550474.png',
#  '../bars/test/665940_h_333480.png',
#  '../bars/test/673731_hv_802074.png',
#  '../bars/test/690397_v_766229.png',
#  '../bars/test/704546_hv_557114.png',
#  '../bars/test/706135_hv_874810.png',
#  '../bars/test/707399_hv_859706.png',
#  '../bars/test/711155_h_386803.png',
#  '../bars/test/712515_v_798645.png',
#  '../bars/test/713963_h_383191.png',
#  '../bars/test/715800_h_384036.png',
#  '../bars/test/717067_v_854261.png',
#  '../bars/test/718253_hv_501242.png',
#  '../bars/test/728157_v_762765.png',
#  '../bars/test/729247_v_1019981.png',
#  '../bars/test/733415_h_471259.png',
#  '../bars/test/744181_h_501242.png',
#  '../bars/test/746795_hv_951710.png',
#  '../bars/test/751772_102.png',
#  '../bars/test/75468_v_210504.png',
#  '../bars/test/759106_v_273053.png',
#  '../bars/test/761809_h_487394.png',
#  '../bars/test/762765_104.png',
#  '../bars/test/763624_6.png',
#  '../bars/test/765321_v_596829.png',
#  '../bars/test/766229_105.png',
#  '../bars/test/784811_h_521815.png',
#  '../bars/test/786902_hv_619523.png',
#  '../bars/test/787177_v_619523.png',
#  '../bars/test/788159_133.png',
#  '../bars/test/788863_h_788159.png',
#  '../bars/test/792084_h_796968.png',
#  '../bars/test/794159_11.png',
#  '../bars/test/794490_h_798645.png',
#  '../bars/test/796968_100.png',
#  '../bars/test/797983_h_794159.png',
#  '../bars/test/798645_101.png',
#  '../bars/test/799879_hv_860611.png',
#  '../bars/test/799977_hv_438723.png',
#  '../bars/test/800843_v_860611.png',
#  '../bars/test/800982_v_438723.png',
#  '../bars/test/802074_36.png',
#  '../bars/test/802341_h_802074.png',
#  '../bars/test/81308_h_147052.png',
#  '../bars/test/815792_hv_59603.png',
#  '../bars/test/817692_hv_215763.png',
#  '../bars/test/831856_v_59603.png',
#  '../bars/test/832812_v_215763.png',
#  '../bars/test/84291_v_796968.png',
#  '../bars/test/849530_v_386803.png',
#  '../bars/test/850357_hv_386803.png',
#  '../bars/test/854261_109.png',
#  '../bars/test/857414_v_404107.png',
#  '../bars/test/859706_112.png',
#  '../bars/test/860611_119.png',
#  '../bars/test/861200_h_923680.png',
#  '../bars/test/869414_h_952345.png',
#  '../bars/test/871021_h_951710.png',
#  '../bars/test/874810_94.png',
#  '../bars/test/875005_hv_521815.png',
#  '../bars/test/87690_v_333480.png',
#  '../bars/test/878447_v_1011307.png',
#  '../bars/test/881269_hv_383191.png',
#  '../bars/test/882513_hv_286167.png',
#  '../bars/test/897230_v_471259.png',
#  '../bars/test/913318_h_974681.png',
#  '../bars/test/918778_h_854261.png',
#  '../bars/test/922307_h_860611.png',
#  '../bars/test/923680_126.png',
#  '../bars/test/928393_hv_404107.png',
#  '../bars/test/929077_h_859706.png',
#  '../bars/test/946381_hv_471259.png',
#  '../bars/test/951710_8.png',
#  '../bars/test/952345_38.png',
#  '../bars/test/957343_hv_1011307.png',
#  '../bars/test/95837_v_763624.png',
#  '../bars/test/960053_h_874810.png',
#  '../bars/test/960254_v_521815.png',
#  '../bars/test/963002_v_383191.png',
#  '../bars/test/965538_v_286167.png',
#  '../bars/test/974681_136.png',
#  '../bars/test/99189_hv_384036.png']

# %%
import pandas as pd

test_df = pd.DataFrame({'path': paths})
test_df["dec"] = test_df.apply(lambda x: int(x['path'].split("/")[-1].split("_")[0]), axis=1)
test_df["bin"] = test_df.apply(lambda x: bin(x['dec']), axis=1)
test_df["class"] = test_df.apply(lambda x: [i for i in reversed(range(20)) if (x['dec'] & 1 << i) != 0], axis=1)
    
print(test_df.shape)
test_df.head()
# Out:
# (200, 4)
#                                  path      dec                     bin  \
# 0  ../bars/test/1000767_h_1018431.png  1000767  0b11110100010100111111
# 1   ../bars/test/1001347_v_794159.png  1001347  0b11110100011110000011
# 2          ../bars/test/1002872_1.png  1002872  0b11110100110101111000
# 3  ../bars/test/1004288_h_1024768.png  1004288  0b11110101001100000000
# 4  ../bars/test/1007758_h_1019981.png  1007758  0b11110110000010001110
#
#                                            class
# 0  [19, 18, 17, 16, 14, 10, 8, 5, 4, 3, 2, 1, 0]
# 1        [19, 18, 17, 16, 14, 10, 9, 8, 7, 1, 0]
# 2    [19, 18, 17, 16, 14, 11, 10, 8, 6, 5, 4, 3]
# 3                 [19, 18, 17, 16, 14, 12, 9, 8]
# 4           [19, 18, 17, 16, 14, 13, 7, 3, 2, 1]

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

target_size = (450, 100)
test_datagen = ImageDataGenerator()
test_generator = test_datagen.flow_from_dataframe(
    dataframe = test_df,
    directory = ".",
    target_size = target_size,
    shuffle = False,
    x_col = 'path',
    y_col = 'class',
    class_mode = 'categorical')
# Out:
# Found 200 validated image filenames belonging to 20 classes.

# %%
cat_model.evaluate(test_generator)
# Out:
# 7/7 [==============================] - 3s 470ms/step - loss: 0.0939 - binary_accuracy: 0.9723
# [0.09390565007925034, 0.9722500443458557]

# %% [markdown]
# # Explore Errors and Confidence Classifying Bars

# %%
prediction = cat_model.predict(test_generator)
prediction
# Out:
# array([[9.99994636e-01, 9.99394536e-01, 9.99995828e-01, ...,
#         9.99999881e-01, 9.99998450e-01, 9.99039948e-01],
#        [1.00000000e+00, 1.00000000e+00, 6.61531718e-10, ...,
#         1.00000000e+00, 9.99998331e-01, 1.00000000e+00],
#        [6.63127764e-07, 2.96091059e-07, 2.24232317e-11, ...,
#         1.00000000e+00, 9.99999881e-01, 1.00000000e+00],
#        ...,
#        [1.24604940e-08, 1.00000000e+00, 8.64513822e-07, ...,
#         9.99999762e-01, 1.00000000e+00, 9.99995947e-01],
#        [1.00000000e+00, 1.10850875e-08, 3.47416215e-12, ...,
#         9.99703109e-01, 1.00000000e+00, 9.99999762e-01],
#        [9.99996662e-01, 4.57223587e-06, 9.99988675e-01, ...,
#         1.27966981e-02, 3.15489690e-03, 5.36163920e-04]], dtype=float32)

# %%
# prediction in binary
test_df["pred_bin"] = ["{}{}{}{}{}{}{}{}{}{}{}{}{}{}{}{}{}{}{}{}"
                   .format(round(x[19]),round(x[18]),round(x[17]),round(x[16]),round(x[15]), 
                           round(x[14]),round(x[13]),round(x[12]),round(x[11]),round(x[10]),
                           round(x[9]), round(x[8]), round(x[7]), round(x[6]), round(x[5]),
                           round(x[4]), round(x[3]), round(x[2]), round(x[1]), round(x[0])) for x in prediction]

#prediction in decimal
vals = []
for p in prediction:
    val = 0
    for i in range(20):
        val += round(p[i]) << i
    vals.append(val)
test_df["pred_dec"] = vals

# number of errors
test_df["errors"] = test_df.apply(lambda x: bin(x["dec"] ^ x["pred_dec"]).count("1"), axis=1)

test_df
# Out:
#                                    path      dec                     bin  \
# 0    ../bars/test/1000767_h_1018431.png  1000767  0b11110100010100111111
# 1     ../bars/test/1001347_v_794159.png  1001347  0b11110100011110000011
# 2            ../bars/test/1002872_1.png  1002872  0b11110100110101111000
# 3    ../bars/test/1004288_h_1024768.png  1004288  0b11110101001100000000
# 4    ../bars/test/1007758_h_1019981.png  1007758  0b11110110000010001110
# ..                                  ...      ...                     ...
# 195    ../bars/test/960254_v_521815.png   960254  0b11101010011011111110
# 196    ../bars/test/963002_v_383191.png   963002  0b11101011000110111010
# 197    ../bars/test/965538_v_286167.png   965538  0b11101011101110100010
# 198         ../bars/test/974681_136.png   974681  0b11101101111101011001
# 199    ../bars/test/99189_hv_384036.png    99189     0b11000001101110101
#
#                                                  class              pred_bin  \
# 0        [19, 18, 17, 16, 14, 10, 8, 5, 4, 3, 2, 1, 0]  11110100010100111111
# 1              [19, 18, 17, 16, 14, 10, 9, 8, 7, 1, 0]  11110100011110000011
# 2          [19, 18, 17, 16, 14, 11, 10, 8, 6, 5, 4, 3]  11110100110101111000
# 3                       [19, 18, 17, 16, 14, 12, 9, 8]  11110101001100000000
# 4                 [19, 18, 17, 16, 14, 13, 7, 3, 2, 1]  11110110000010001110
# ..                                                 ...                   ...
# 195   [19, 18, 17, 15, 13, 10, 9, 7, 6, 5, 4, 3, 2, 1]  11101010011011111110
# 196         [19, 18, 17, 15, 13, 12, 8, 7, 5, 4, 3, 1]  11101011000110111110
# 197        [19, 18, 17, 15, 13, 12, 11, 9, 8, 7, 5, 1]  11101011101110100010
# 198  [19, 18, 17, 15, 14, 12, 11, 10, 9, 8, 6, 4, 3...  11101101111101011001
# 199                      [16, 15, 9, 8, 6, 5, 4, 2, 0]  00001000001101110101
#
#      pred_dec  errors
# 0     1000767       0
# 1     1001347       0
# 2     1002872       0
# 3     1004288       0
# 4     1007758       0
# ..        ...     ...
# 195    960254       0
# 196    963006       1
# 197    965538       0
# 198    974681       0
# 199     33653       1
#
# [200 rows x 7 columns]

# %%
test_df["pred_class"] =  [[cl for cl, x in enumerate(prediction[i]) if x>0.5] for i in range(len(prediction))]

# %%
test_df["error_classes"] = [list(set(test_df["pred_class"][i]).symmetric_difference(set(test_df["class"][i]))) for i in range(len(test_df))]

# %%
test_df[["dec", "errors", "class", "pred_class", "error_classes"]]
# Out:
#          dec  errors                                              class  \
# 0    1000767       0      [19, 18, 17, 16, 14, 10, 8, 5, 4, 3, 2, 1, 0]
# 1    1001347       0            [19, 18, 17, 16, 14, 10, 9, 8, 7, 1, 0]
# 2    1002872       0        [19, 18, 17, 16, 14, 11, 10, 8, 6, 5, 4, 3]
# 3    1004288       0                     [19, 18, 17, 16, 14, 12, 9, 8]
# 4    1007758       0               [19, 18, 17, 16, 14, 13, 7, 3, 2, 1]
# ..       ...     ...                                                ...
# 195   960254       0   [19, 18, 17, 15, 13, 10, 9, 7, 6, 5, 4, 3, 2, 1]
# 196   963002       1         [19, 18, 17, 15, 13, 12, 8, 7, 5, 4, 3, 1]
# 197   965538       0        [19, 18, 17, 15, 13, 12, 11, 9, 8, 7, 5, 1]
# 198   974681       0  [19, 18, 17, 15, 14, 12, 11, 10, 9, 8, 6, 4, 3...
# 199    99189       1                      [16, 15, 9, 8, 6, 5, 4, 2, 0]
#
#                                             pred_class error_classes
# 0        [0, 1, 2, 3, 4, 5, 8, 10, 14, 16, 17, 18, 19]            []
# 1              [0, 1, 7, 8, 9, 10, 14, 16, 17, 18, 19]            []
# 2          [3, 4, 5, 6, 8, 10, 11, 14, 16, 17, 18, 19]            []
# 3                       [8, 9, 12, 14, 16, 17, 18, 19]            []
# 4                 [1, 2, 3, 7, 13, 14, 16, 17, 18, 19]            []
# ..                                                 ...           ...
# 195   [1, 2, 3, 4, 5, 6, 7, 9, 10, 13, 15, 17, 18, 19]            []
# 196      [1, 2, 3, 4, 5, 7, 8, 12, 13, 15, 17, 18, 19]           [2]
# 197        [1, 5, 7, 8, 9, 11, 12, 13, 15, 17, 18, 19]            []
# 198  [0, 3, 4, 6, 8, 9, 10, 11, 12, 14, 15, 17, 18,...            []
# 199                          [0, 2, 4, 5, 6, 8, 9, 15]          [16]
#
# [200 rows x 5 columns]

# %%
from numpy import nan

# Average confidence of correct predictions
avg_conf_corr = []
avg_conf_err = []
lowest_err_conf = []
sec_lowest_err_conf = []
lowest_corr_conf = []
for idx, pred in enumerate(prediction):
    errors = test_df["errors"][idx]
    conf_corr = 0
    conf_err = 0
    l_err_conf = 2
    l2_err_conf = 2
    l_corr_conf = 2
    for i in range(len(pred)):
        conf = 1 - min(abs(pred[i]-1), pred[i])
        if i in test_df["error_classes"][idx]:            
            conf_err += conf/errors
            if conf < l_err_conf:
                l_err_conf = conf
            elif conf < l2_err_conf:
                l2_err_conf = conf
        else:
            conf_corr += conf/(len(pred) - errors)
            if conf < l_corr_conf:
                l_corr_conf = conf
            
    avg_conf_corr.append(conf_corr)
    avg_conf_err.append(conf_err)
    lowest_err_conf.append(l_err_conf)
    sec_lowest_err_conf.append(l2_err_conf)
    lowest_corr_conf.append(l_corr_conf)    
    
test_df["avg_conf_corr"] = avg_conf_corr
test_df["avg_conf_err"] = avg_conf_err
test_df["lowest_err_conf"] = lowest_err_conf
test_df["sec_lowest_err_conf"] = sec_lowest_err_conf
test_df["lowest_corr_conf"] = lowest_corr_conf
test_df.loc[test_df["sec_lowest_err_conf"] == 2,"sec_lowest_err_conf"] = nan
test_df.loc[test_df["lowest_err_conf"] == 2,"lowest_err_conf"] = nan

# %%
test_df[["errors", "class", "pred_class", "error_classes", "avg_conf_corr", "avg_conf_err", "lowest_corr_conf", "lowest_err_conf", "sec_lowest_err_conf"]]
# Out:
#      errors                                              class  \
# 0         0      [19, 18, 17, 16, 14, 10, 8, 5, 4, 3, 2, 1, 0]
# 1         0            [19, 18, 17, 16, 14, 10, 9, 8, 7, 1, 0]
# 2         0        [19, 18, 17, 16, 14, 11, 10, 8, 6, 5, 4, 3]
# 3         0                     [19, 18, 17, 16, 14, 12, 9, 8]
# 4         0               [19, 18, 17, 16, 14, 13, 7, 3, 2, 1]
# ..      ...                                                ...
# 195       0   [19, 18, 17, 15, 13, 10, 9, 7, 6, 5, 4, 3, 2, 1]
# 196       1         [19, 18, 17, 15, 13, 12, 8, 7, 5, 4, 3, 1]
# 197       0        [19, 18, 17, 15, 13, 12, 11, 9, 8, 7, 5, 1]
# 198       0  [19, 18, 17, 15, 14, 12, 11, 10, 9, 8, 6, 4, 3...
# 199       1                      [16, 15, 9, 8, 6, 5, 4, 2, 0]
#
#                                             pred_class error_classes  \
# 0        [0, 1, 2, 3, 4, 5, 8, 10, 14, 16, 17, 18, 19]            []
# 1              [0, 1, 7, 8, 9, 10, 14, 16, 17, 18, 19]            []
# 2          [3, 4, 5, 6, 8, 10, 11, 14, 16, 17, 18, 19]            []
# 3                       [8, 9, 12, 14, 16, 17, 18, 19]            []
# 4                 [1, 2, 3, 7, 13, 14, 16, 17, 18, 19]            []
# ..                                                 ...           ...
# 195   [1, 2, 3, 4, 5, 6, 7, 9, 10, 13, 15, 17, 18, 19]            []
# 196      [1, 2, 3, 4, 5, 7, 8, 12, 13, 15, 17, 18, 19]           [2]
# 197        [1, 5, 7, 8, 9, 11, 12, 13, 15, 17, 18, 19]            []
# 198  [0, 3, 4, 6, 8, 9, 10, 11, 12, 14, 15, 17, 18,...            []
# 199                          [0, 2, 4, 5, 6, 8, 9, 15]          [16]
#
#      avg_conf_corr  avg_conf_err  lowest_corr_conf  lowest_err_conf  \
# 0         0.961258      0.000000          0.691036              NaN
# 1         0.999896      0.000000          0.998245              NaN
# 2         0.996682      0.000000          0.959753              NaN
# 3         0.990435      0.000000          0.917470              NaN
# 4         0.991611      0.000000          0.850669              NaN
# ..             ...           ...               ...              ...
# 195       0.999335      0.000000          0.995115              NaN
# 196       0.975757      0.995276          0.702527         0.995276
# 197       0.999820      0.000000          0.997457              NaN
# 198       0.999731      0.000000          0.994947              NaN
# 199       0.999119      0.612693          0.987203         0.612693
#
#      sec_lowest_err_conf
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ..                   ...
# 195                  NaN
# 196                  NaN
# 197                  NaN
# 198                  NaN
# 199                  NaN
#
# [200 rows x 9 columns]

# %%
test_df["succ_corr"] = test_df["lowest_err_conf"]<test_df["lowest_corr_conf"]
test_df["succ_corr"][test_df["errors"]>0][test_df["errors"]<6].value_counts(normalize=True)
# Out:
# True     0.611111
# False    0.388889
# Name: succ_corr, dtype: float64

# %%
test_df["succ_2corr"] = test_df["sec_lowest_err_conf"]<test_df["lowest_corr_conf"]
test_df["succ_2corr"][test_df["errors"]>1][test_df["errors"]<6].value_counts(normalize=True)
# Out:
# False    0.944444
# True     0.055556
# Name: succ_2corr, dtype: float64
